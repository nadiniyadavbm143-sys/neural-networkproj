# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

# %%
X, y = make_classification(n_samples=1000, n_features=20, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("Data Ready")
# Out:
# Data Ready

# %%
X_train.shape[1]
# Out:
# 20

# %%
#basline performance
model=Sequential([
    Dense(32,activation='relu',input_shape=(X_train.shape[1],)),
    Dense(16,activation='relu'),
    Dense(1,activation='sigmoid')
])
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history=model.fit(X_train,y_train,epochs=50,validation_data=(X_test,y_test))
# Out:
# C:\Users\Nandini b m\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.5400 - loss: 0.7528 - val_accuracy: 0.7000 - val_loss: 0.6204
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7063 - loss: 0.5877 - val_accuracy: 0.7800 - val_loss: 0.5404
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7925 - loss: 0.5174 - val_accuracy: 0.8450 - val_loss: 0.4828
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8250 - loss: 0.4623 - val_accuracy: 0.8800 - val_loss: 0.4317
# Epoch 5/50
# ...

# %%
#baseline performance
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend('x','y')
plt.title("overfitting example")
plt.show()
# Out:
# C:\Users\Nandini b m\AppData\Local\Temp\ipykernel_2892\3327306474.py:4: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   plt.legend('x','y')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras import regularizers
model_reg=Sequential([
    Dense(32,activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    Dense(16,activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    Dense(8,activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    Dense(1,activation='sigmoid')
])

# %%
model_reg.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
history_reg=model_reg.fit(X_train,y_train,epochs=50,validation_data=(X_test,y_test))
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.4150 - loss: 1.2697 - val_accuracy: 0.4800 - val_loss: 1.2227
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5838 - loss: 1.1797 - val_accuracy: 0.6300 - val_loss: 1.1390
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7025 - loss: 1.0903 - val_accuracy: 0.7950 - val_loss: 1.0303
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7825 - loss: 0.9763 - val_accuracy: 0.8250 - val_loss: 0.9004
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8263 - loss: 0.8574 - val_accuracy: 0.8350 - val_loss: 0.8016
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8537 - loss: 0.7705 - val_accuracy: 0.8600 - val_loss: 0.7336
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8675 - loss: 0.7089 - val_accuracy: 0.8600 - val_loss: 0.6905
# Epoch 8/50
# ...

# %%
plt.plot(history_reg.history['accuracy'])
plt.plot(history_reg.history['val_accuracy'])
plt.legend('x','y')
plt.title("regularizer example")
plt.show()
# Out:
# C:\Users\Nandini b m\AppData\Local\Temp\ipykernel_2892\214073283.py:3: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   plt.legend('x','y')

# %%
#earlystopping
early_stop=EarlyStopping(monitor='val_loss',patience=6)
model_es=Sequential([
    Dense(32,activation='relu'),
    Dense(16,activation='relu'),
    Dense(8,activation='relu'),
    Dense(1,activation='sigmoid')
])

# %%
model_es.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
history_es=model_es.fit(X_train,y_train,epochs=50,validation_data=(X_test,y_test),callbacks=[early_stop],verbose=1)
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9413 - loss: 0.1822 - val_accuracy: 0.8650 - val_loss: 0.3554
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9413 - loss: 0.1792 - val_accuracy: 0.8600 - val_loss: 0.3617
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9413 - loss: 0.1750 - val_accuracy: 0.8600 - val_loss: 0.3548
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9450 - loss: 0.1710 - val_accuracy: 0.8650 - val_loss: 0.3601
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9450 - loss: 0.1678 - val_accuracy: 0.8650 - val_loss: 0.3613
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9500 - loss: 0.1631 - val_accuracy: 0.8750 - val_loss: 0.3718

# %%
plt.plot(history_es.history['accuracy'])
plt.plot(history_es.history['val_accuracy'])
plt.legend('x','y')
plt.title("earlystopping example")
plt.show()
# Out:
# C:\Users\Nandini b m\AppData\Local\Temp\ipykernel_2892\2153019852.py:3: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   plt.legend('x','y')
